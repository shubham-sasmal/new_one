# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham-sasmal/new_one/blob/main/loop_related_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sum of natural number
def sum_natural(n):
    return n * (n + 1) // 2
n = int(input("Enter a natural number: "))
result = sum_natural(n)
print("Sum of first", n, "natural numbers =", result)
# Out:
# Enter a natural number: 5
# Sum of first 5 natural numbers = 15

# %%
# sum of natural number

def sum_natural(n):
    total = 0
    for i in range(1, n + 1):
        total = total + i
    return total
n = int(input("Enter a natural number: "))
result = sum_natural(n)
print("Sum of first", n, "natural numbers =", result)
# Out:
# Enter a natural number: 5
# Sum of first 5 natural numbers = 15

# %%
# factorial of a number
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
num = int(input("Enter a number: "))
if num < 0:
    print("Factorial does not exist for negative numbers")
else:
    print("Factorial of", num, "is", factorial(num))
# Out:
# Enter a number: 5
# Factorial of 5 is 120

# %%
# sum of squares of first n natural numbers
n = int(input("Enter a number: "))
s = 0
for i in range(1, n + 1):
    s = s + i**2
print("Sum =", s)
# Out:
# Enter a number: 100
# Sum = 338350

# %%
# fibonacci series
n = int(input("Enter the number of terms: "))
a = 0
b = 1
print("Fibonacci Series:")
for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c
# Out:
# Enter the number of terms: 7
# Fibonacci Series:
# 0 1 1 2 3 5 8
